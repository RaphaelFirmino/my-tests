# %%
import pyautogui
import time
import pyperclip
import panda as pd

# %%
pyautogui.PAUSE = 1 # pausa de 1 segundo para cada linha
pyautogui.alert("Vai começar, aperte OK e não mexa em nada")

pyautogui.hotkey('ctrl', 't') # abrir nova aba e ir até o drive
link = "https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing"
pyperclip.copy(link)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(7)

pyautogui.click(x, y, clicks=2) # localizar arquivo e baixar
time.sleep(2)
pyautogui.click(x, y, button='right')
pyautogui.click(x, y)
time.sleep(10)

planilha = pd.read_excel(r"Caminho do arquivo") # abrir planilha e coletar os dados
display(planilha)
faturamento = planilha['Valor Final'].sum()
quantidade = planilha['Quantidade'].sum()

pyautogui.hotkey('ctrl', 't') # abrir e-mail
gmail = "mail.google.com"
pyperclip.copy(gmail)
pyautogui.hotkey('ctrl','v')
pyautogui.press('enter')
time.sleep(5)

pyautogui.click(x, y) # escrever e-mail
pyautogui.write('raphaelfirminooliveira+diretoria@gmail.com')
pyautogui.press('tab')
pyautogui.press('tab')
assunto = "Relatório de Vendas de Ontem"
pyperclip.copy(assunto)
pyautogui.hotkey("ctrl", 'v')
pyautogui.press("tab")
texto = f'''
Prezados, bom dia

O faturamento de ontem foi de R$ {faturamento:,.2f}
A quantidade de produtos foi de: {quantidade:,}

Abs
Raphael Firmino
'''
pyperclip.copy(texto)
pyautogui.hotkey("ctrl", 'v')
pyautogui.hotkey('ctrl','enter')

pyautogui.alert("Fim da automação, o computador voltou a ser seu!")

# %%
'''import pyautogui # descobrir posição da tela para clicar
import time
time.sleep(7)
print(pyautogui.position())
pyautogui.alert("Posição Registrada")'''
